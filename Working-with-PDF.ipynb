# %%
# pip install PyPDF2

# %%
import PyPDF2

# %%
myFile = open(r'C:\Users\Muhammad\Documents\AI\Artificial intelligence\Artificial Intelligence A Modern Approach.pdf',mode='rb')

# %%
pdf_reader = PyPDF2.PdfFileReader(myFile)

# %%
pdf_reader.numPages
# Out:
# 1151

# %%
pg=pdf_reader.getPage(8)

# %%
ff = pg.extractText()

# %%
# print(ff)
# Out:
# viiiPreface
# Overviewofthebook
# Themainunifyingthemeistheideaofan
# intelligentagent
# .WedeÞneAIasthestudyof
# agentsthatreceiveperceptsfromtheenvironmentandperformactions.Eachsuchagentim-
# plementsafunctionthatmapsperceptsequencestoactions,andwecoverdifferentwaysto
#
# representthesefunctions,suchasreactiveagents,real-timeplanners,anddecision-theoretic
#
# systems.Weexplaintheroleoflearningasextendingthereachofthedesignerintounknown
#
# environments,andweshowhowthatroleconstrainsagentdesign,favoringexplicitknowl-
#
# edgerepresentationandreasoning.WetreatroboticsandvisionnotasindependentlydeÞned
#
# problems,butasoccurringintheserviceofachievinggoals.Westresstheimportanceofthe
#
# taskenvironmentindeterminingtheappropriateagentdesign.
# Ourprimaryaimistoconveythe
# ideasthathaveemergedoverthepastÞftyyearsofAI
# researchandthepasttwomillenniaofrelatedwork.Wehavetriedtoavoidexcessiveformal-
#
# ityinthepresentationoftheseideaswhileretainingprecision.Wehaveincludedpseudocode
# ...

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc = nlp(ff)

# %%
i=0
tble = []
for token in doc:
    tble.append(token.text)
    print(str(i)+"  "+token.text)
    i+=1
# Out:
# 0  viiiPreface
# 1
#
# 2  Overviewofthebook
# 3
#
# 4  Themainunifyingthemeistheideaofan
# 5
#
# 6  intelligentagent
# 7
#
# 8  .WedeÞneAIasthestudyof
# 9
#
# 10  agentsthatreceiveperceptsfromtheenvironmentandperformactions
# 11  .
# 12  Eachsuchagentim-
# 13
#
# 14  plementsafunctionthatmapsperceptsequencestoactions
# 15  ,
# 16  andwecoverdifferentwaysto
# 17
#
#
# 18  representthesefunctions
# 19  ,
# 20  suchasreactiveagents
# 21  ,
# 22  real
# 23  -
# 24  timeplanners
# 25  ,
# 26  anddecision
# 27  -
# 28  theoretic
# 29
#
#
# 30  systems
# 31  .
# 32  Weexplaintheroleoflearningasextendingthereachofthedesignerintounknown
# 33
#
#
# 34  environments
# 35  ,
# 36  andweshowhowthatroleconstrainsagentdesign
# 37  ,
# 38  favoringexplicitknowl-
# 39
#
#
# 40  edgerepresentationandreasoning
# 41  .
# 42  WetreatroboticsandvisionnotasindependentlydeÞned
# 43
#
#
# 44  problems
# 45  ,
# 46  butasoccurringintheserviceofachievinggoals
# 47  .
# 48  Westresstheimportanceofthe
# 49
#
#
# ...

# %%
# tble
# for i in tble:
#     if tble[i]==int('\n'):
#         tble.remove(tble[i])
        
        
# # for t in tble:
# #     if '\n' in tble:
# #         tble.remove(t)
# # # tble
# tble

# %%
# pdf_text = [0]
# for p in range(pdf_reader.numPages):
#     page = pdf_reader.getPage(p)
#     pdf_text.append(page.extractText())

# %%
# pdf_text

# %%
tble
# Out:
# ['viiiPreface',
#  '\n',
#  'Overviewofthebook',
#  '\n',
#  'Themainunifyingthemeistheideaofan',
#  '\n',
#  'intelligentagent',
#  '\n',
#  '.WedeÞneAIasthestudyof',
#  '\n',
#  'agentsthatreceiveperceptsfromtheenvironmentandperformactions',
#  '.',
#  'Eachsuchagentim-',
#  '\n',
#  'plementsafunctionthatmapsperceptsequencestoactions',
#  ',',
#  'andwecoverdifferentwaysto',
#  '\n\n',
#  'representthesefunctions',
#  ',',
#  'suchasreactiveagents',
#  ',',
#  'real',
#  '-',
#  'timeplanners',
#  ',',
#  'anddecision',
#  '-',
#  'theoretic',
#  '\n\n',
#  'systems',
#  '.',
#  'Weexplaintheroleoflearningasextendingthereachofthedesignerintounknown',
#  '\n\n',
#  'environments',
#  ',',
#  'andweshowhowthatroleconstrainsagentdesign',
#  ',',
#  'favoringexplicitknowl-',
#  '\n\n',
#  'edgerepresentationandreasoning',
#  '.',
#  'WetreatroboticsandvisionnotasindependentlydeÞned',
#  '\n\n',
#  'problems',
#  ',',
#  'butasoccurringintheserviceofachievinggoals',
#  '.',
# ...
