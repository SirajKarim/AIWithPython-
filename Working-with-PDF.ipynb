# %%
# pip install PyPDF2

# %%
import PyPDF2

# %%
myFile = open(r'C:\Users\Muhammad\Documents\AI\Artificial intelligence\Artificial Intelligence A Modern Approach.pdf',mode='rb')

# %%
pdf_reader = PyPDF2.PdfFileReader(myFile)

# %%
pdf_reader.numPages
# Out:
# 1151

# %%
pg=pdf_reader.getPage(14)

# %%
ff = pg.extractText()

# %%
print(ff)
# Out:
# xiv
# Contents
# 5.6PartiallyObservableGames.........................180
# 5.7State-of-the-ArtGamePrograms...
# ...................185
# 5.8AlternativeApproaches...........................187
#
# 5.9Summary,BibliographicalandHistoricalNotes,Exercises.........189
# 6ConstraintSatisfactionProblems202
# 6.1DeÞningConstraintSatisfactionProblems.................202
#
# 6.2ConstraintPropagation:InferenceinCSPs.................208
#
# 6.3BacktrackingSearchforCSPs........................214
#
# 6.4LocalSearchforCSPs............................220
#
# 6.5TheStructureofProblems..........................222
#
# 6.6Summary,BibliographicalandHistoricalNotes,Exercises.........227
# IIIKnowledge,reasoning,andplanning
# 7LogicalAgents234
# 7.1Knowledge-BasedAgents.
# .........................235
# 7.2TheWumpusWorld.............................236
#
# 7.3Logic.....................................240
#
# 7.4PropositionalLogic:AVerySimpleLogic...
# ..............243
# 7.5PropositionalTheoremProving
# .......................249
# 7.6EffectivePropositionalModelChecking
# ..................259
# 7.7AgentsBasedonPropositionalLogic.
# ...................265
# 7.8Summary,BibliographicalandHistoricalNotes,Exercises.........274
# 8First-OrderLogic285
# 8.1RepresentationRevisited.
# .........................285
# 8.2SyntaxandSemanticsofFirst-OrderLogic.................290
#
# 8.3UsingFirst-OrderLogic...........................300
#
# 8.4KnowledgeEngineeringinFirst-OrderLogic................307
#
# 8.5Summary,BibliographicalandHistoricalNotes,Exercises.........313
# 9InferenceinFirst-OrderLogic322
# 9.1Propositionalvs.First-OrderInference
# ...................322
# 9.2UniÞcationandLifting..
# .........................325
# 9.3ForwardChaining..............................330
#
# 9.4BackwardChaining.............................337
#
# 9.5Resolution..................................345
#
# 9.6Summary,BibliographicalandHistoricalNotes,Exercises.........357
# 10ClassicalPlanning366
# 10.1DeÞnitionofClassicalPlanning
# .......................366
# 10.2AlgorithmsforPlanningasState-SpaceSearch...............373
#
# 10.3PlanningGraphs...............................379

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc = nlp(ff)

# %%
tble = []
for token in doc:
    tble.append(token.text)
    print(token.text)
# Out:
# xiv
#
#
# Contents
#
#
# 5.6PartiallyObservableGames
# .........................
# 180
#
#
# 5.7State
# -
# of
# -
# the
# -
# ArtGamePrograms
# ...
#
#
# ...................
# 185
#
#
# 5.8AlternativeApproaches
# ...........................
# 187
#
#
#
# 5.9Summary
# ,
# BibliographicalandHistoricalNotes
# ,
# Exercises
# .........
# 189
#
#
# 6ConstraintSatisfactionProblems202
#
#
# 6.1DeÞningConstraintSatisfactionProblems
# .................
# 202
#
#
#
# 6.2ConstraintPropagation
# :
# InferenceinCSPs
# .................
# 208
#
#
#
# 6.3BacktrackingSearchforCSPs
# ........................
# 214
#
#
#
# 6.4LocalSearchforCSPs
# ............................
# 220
#
#
#
# 6.5TheStructureofProblems
# ..........................
# 222
#
#
#
# 6.6Summary
# ,
# BibliographicalandHistoricalNotes
# ,
# Exercises
# .........
# 227
#
#
# IIIKnowledge
# ,
# reasoning
# ,
# andplanning
#
#
# 7LogicalAgents234
#
#
# 7.1Knowledge
# -
# BasedAgents
# .
#
#
# .........................
# 235
#
#
# 7.2TheWumpusWorld
# .............................
# 236
#
#
#
# 7.3Logic
# .....................................
# 240
#
#
#
# 7.4PropositionalLogic
# :
# AVerySimpleLogic
# ...
#
#
# ..............
# 243
#
#
# 7.5PropositionalTheoremProving
#
#
# .......................
# 249
#
#
# 7.6EffectivePropositionalModelChecking
#
#
# ..................
# 259
#
#
# 7.7AgentsBasedonPropositionalLogic
# .
#
#
# ...................
# 265
#
#
# 7.8Summary
# ,
# BibliographicalandHistoricalNotes
# ,
# Exercises
# .........
# 274
#
#
# 8First
# -
# OrderLogic285
#
#
# 8.1RepresentationRevisited
# .
#
#
# .........................
# 285
#
#
# 8.2SyntaxandSemanticsofFirst
# -
# OrderLogic
# .................
# 290
#
#
#
# 8.3UsingFirst
# -
# OrderLogic
# ...........................
# 300
#
#
#
# 8.4KnowledgeEngineeringinFirst
# -
# OrderLogic
# ................
# 307
#
#
#
# 8.5Summary
# ,
# BibliographicalandHistoricalNotes
# ,
# Exercises
# .........
# 313
#
#
# 9InferenceinFirst
# -
# OrderLogic322
#
#
# 9.1Propositionalvs
# .
# First
# -
# OrderInference
#
#
# ...................
# 322
#
#
# 9.2UniÞcationandLifting
# ..
#
#
# .........................
# 325
#
#
# 9.3ForwardChaining
# ..............................
# 330
#
#
#
# 9.4BackwardChaining
# .............................
# 337
#
#
#
# 9.5Resolution
# ..................................
# 345
#
#
#
# 9.6Summary
# ,
# BibliographicalandHistoricalNotes
# ,
# Exercises
# .........
# 357
#
#
# 10ClassicalPlanning366
#
#
# 10.1DeÞnitionofClassicalPlanning
#
#
# .......................
# 366
#
#
# 10.2AlgorithmsforPlanningasState
# -
# SpaceSearch
# ...............
# 373
#
#
#
# 10.3PlanningGraphs
# ...............................
# 379

# %%
tble
# Out:
# ['xiv',
#  '\n',
#  'Contents',
#  '\n',
#  '5.6PartiallyObservableGames',
#  '.........................',
#  '180',
#  '\n',
#  '5.7State',
#  '-',
#  'of',
#  '-',
#  'the',
#  '-',
#  'ArtGamePrograms',
#  '...',
#  '\n',
#  '...................',
#  '185',
#  '\n',
#  '5.8AlternativeApproaches',
#  '...........................',
#  '187',
#  '\n\n',
#  '5.9Summary',
#  ',',
#  'BibliographicalandHistoricalNotes',
#  ',',
#  'Exercises',
#  '.........',
#  '189',
#  '\n',
#  '6ConstraintSatisfactionProblems202',
#  '\n',
#  '6.1DeÞningConstraintSatisfactionProblems',
#  '.................',
#  '202',
#  '\n\n',
#  '6.2ConstraintPropagation',
#  ':',
#  'InferenceinCSPs',
#  '.................',
#  '208',
#  '\n\n',
#  '6.3BacktrackingSearchforCSPs',
#  '........................',
#  '214',
#  '\n\n',
#  '6.4LocalSearchforCSPs',
#  '............................',
#  '220',
#  '\n\n',
#  '6.5TheStructureofProblems',
#  '..........................',
#  '222',
#  '\n\n',
#  '6.6Summary',
#  ',',
#  'BibliographicalandHistoricalNotes',
#  ',',
#  'Exercises',
#  '.........',
#  '227',
#  '\n',
#  'IIIKnowledge',
#  ',',
#  'reasoning',
#  ',',
#  'andplanning',
#  '\n',
#  '7LogicalAgents234',
#  '\n',
#  '7.1Knowledge',
#  '-',
#  'BasedAgents',
#  '.',
#  '\n',
#  '.........................',
#  '235',
#  '\n',
#  '7.2TheWumpusWorld',
#  '.............................',
#  '236',
#  '\n\n',
#  '7.3Logic',
#  '.....................................',
#  '240',
#  '\n\n',
#  '7.4PropositionalLogic',
#  ':',
#  'AVerySimpleLogic',
#  '...',
#  '\n',
#  '..............',
#  '243',
#  '\n',
#  '7.5PropositionalTheoremProving',
#  '\n',
#  '.......................',
#  '249',
#  '\n',
#  '7.6EffectivePropositionalModelChecking',
#  '\n',
#  '..................',
#  '259',
#  '\n',
#  '7.7AgentsBasedonPropositionalLogic',
#  '.',
#  '\n',
#  '...................',
#  '265',
#  '\n',
#  '7.8Summary',
#  ',',
#  'BibliographicalandHistoricalNotes',
#  ',',
#  'Exercises',
#  '.........',
#  '274',
#  '\n',
#  '8First',
#  '-',
#  'OrderLogic285',
#  '\n',
#  '8.1RepresentationRevisited',
#  '.',
#  '\n',
#  '.........................',
#  '285',
#  '\n',
#  '8.2SyntaxandSemanticsofFirst',
#  '-',
#  'OrderLogic',
#  '.................',
#  '290',
#  '\n\n',
#  '8.3UsingFirst',
#  '-',
#  'OrderLogic',
#  '...........................',
#  '300',
#  '\n\n',
#  '8.4KnowledgeEngineeringinFirst',
#  '-',
#  'OrderLogic',
#  '................',
#  '307',
#  '\n\n',
#  '8.5Summary',
#  ',',
#  'BibliographicalandHistoricalNotes',
#  ',',
#  'Exercises',
#  '.........',
#  '313',
#  '\n',
#  '9InferenceinFirst',
#  '-',
#  'OrderLogic322',
#  '\n',
#  '9.1Propositionalvs',
#  '.',
#  'First',
#  '-',
#  'OrderInference',
#  '\n',
#  '...................',
#  '322',
#  '\n',
#  '9.2UniÞcationandLifting',
#  '..',
#  '\n',
#  '.........................',
#  '325',
#  '\n',
#  '9.3ForwardChaining',
#  '..............................',
#  '330',
#  '\n\n',
#  '9.4BackwardChaining',
#  '.............................',
#  '337',
#  '\n\n',
#  '9.5Resolution',
#  '..................................',
#  '345',
#  '\n\n',
#  '9.6Summary',
#  ',',
#  'BibliographicalandHistoricalNotes',
#  ',',
#  'Exercises',
#  '.........',
#  '357',
#  '\n',
#  '10ClassicalPlanning366',
#  '\n',
#  '10.1DeÞnitionofClassicalPlanning',
#  '\n',
#  '.......................',
#  '366',
#  '\n',
#  '10.2AlgorithmsforPlanningasState',
#  '-',
#  'SpaceSearch',
#  '...............',
#  '373',
#  '\n\n',
#  '10.3PlanningGraphs',
#  '...............................',
#  '379',
#  '\n']

# %%
pdf_text = [0]
for p in range(pdf_reader.numPages):
    page = pdf_reader.getPage(p)
    pdf_text.append(page.extractText())

# %%
pdf_text
